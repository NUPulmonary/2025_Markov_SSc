# %%
import matplotlib as mpl
import scanpy as sc
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../lib")
import sc_utils

# %%
ds = sc.read_h5ad("../../data/01ssc-bal/scanpy/SSc_SSc8/SSc_SSc8.h5ad")

# %%
mpl.rcParams["figure.figsize"] = (6, 6)

# %%
fig = sc_utils.feature_plot(ds, "MARCO", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-marco.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "FABP4", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-fabp4.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "CCL2", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-ccl2.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "CCL3", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-ccl3.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "SEPP1", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-sepp1.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "IFI27", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-ifi27.png")
fig

# %%
fig = sc_utils.feature_plot(ds, "F13A1", gridsize=(120, 60), linewidths=0.4)
fig.axes[0].set_xlim(-10, 5)
fig.axes[0].set_ylim(-5.2, 6)
fig.savefig("02ssc-ssc8-f13a1.png")
fig
